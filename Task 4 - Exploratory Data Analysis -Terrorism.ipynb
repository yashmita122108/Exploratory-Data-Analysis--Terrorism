# %% [markdown]
# # Graduate Rotational Internship Program

# %% [markdown]
# # The Sparks Foundation

# %% [markdown]
# # Task - 4 : Exploratory Data Analysis - Terrorism

# %% [markdown]
# # Author : Yashmita

# %% [markdown]
# **Problem statement**
#
# Perform ‘Exploratory Data Analysis’ on dataset ‘Global Terrorism’
#
# As a security/defense analyst, try to find out the hot zone of terrorism.
#
# What all security issues and insights you can derive by EDA?

# %% [markdown]
# **Dataset** - https://bit.ly/2TK5Xn5

# %% [markdown]
# # Step 1 - Importing the required libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %% [markdown]
# # Step 2 - Importing the Dataset

# %%
df = pd.read_csv('globalterrorismdb_0718dist.csv', 
                 encoding= 'ISO-8859-1', low_memory= False)
df.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  1.970000e+11   1970       7     2        NaN         0        NaN       58
# 1  1.970000e+11   1970       0     0        NaN         0        NaN      130
# 2  1.970010e+11   1970       1     0        NaN         0        NaN      160
# 3  1.970010e+11   1970       1     0        NaN         0        NaN       78
# 4  1.970010e+11   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
# ...

# %% [markdown]
# # Step 3 - Data Pre-processing

# %%
df.shape
# Out:
# (181691, 135)

# %%
df.info
# Out:
# <bound method DataFrame.info of              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 0       1.970000e+11   1970       7     2        NaN         0        NaN
# 1       1.970000e+11   1970       0     0        NaN         0        NaN
# 2       1.970010e+11   1970       1     0        NaN         0        NaN
# 3       1.970010e+11   1970       1     0        NaN         0        NaN
# 4       1.970010e+11   1970       1     0        NaN         0        NaN
# ...              ...    ...     ...   ...        ...       ...        ...
# 181686  2.017120e+11   2017      12    31        NaN         0        NaN
# 181687  2.017120e+11   2017      12    31        NaN         0        NaN
# 181688  2.017120e+11   2017      12    31        NaN         0        NaN
# 181689  2.017120e+11   2017      12    31        NaN         0        NaN
# 181690  2.017120e+11   2017      12    31        NaN         0        NaN
#
# ...

# %%
df.describe()
# Out:
#             eventid          iyear         imonth           iday  \
# count  1.816910e+05  181691.000000  181691.000000  181691.000000
# mean   2.002704e+11    2002.638997       6.467277      15.505644
# std    1.325955e+09      13.259430       3.388303       8.814045
# min    1.970000e+11    1970.000000       0.000000       0.000000
# 25%    1.991020e+11    1991.000000       4.000000       8.000000
# 50%    2.009020e+11    2009.000000       6.000000      15.000000
# 75%    2.014080e+11    2014.000000       9.000000      23.000000
# max    2.017120e+11    2017.000000      12.000000      31.000000
#
#             extended        country         region       latitude  \
# count  181691.000000  181691.000000  181691.000000  177135.000000
# mean        0.045346     131.968501       7.160938      23.498343
# std         0.208063     112.414535       2.933408      18.569242
# min         0.000000       4.000000       1.000000     -53.154613
# ...

# %%
df.columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region',
#        ...
#        'addnotes', 'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG',
#        'INT_IDEO', 'INT_MISC', 'INT_ANY', 'related'],
#       dtype='object', length=135)

# %%
#checking values unique in a coloumn 
for i in df.columns:
    print(i,len(df[i].unique()))
# Out:
# eventid 576
# iyear 47
# imonth 13
# iday 32
# approxdate 2245
# extended 2
# resolution 1860
# country 205
# country_txt 205
# region 12
# region_txt 12
# provstate 2856
# city 36675
# latitude 48323
# longitude 48040
# specificity 6
# vicinity 3
# location 44110
# summary 112493
# crit1 2
# crit2 2
# crit3 2
# doubtterr 4
# alternative 6
# alternative_txt 6
# multiple 3
# success 2
# suicide 2
# attacktype1 9
# attacktype1_txt 9
# attacktype2 10
# attacktype2_txt 10
# attacktype3 9
# attacktype3_txt 9
# targtype1 22
# targtype1_txt 22
# targsubtype1 113
# targsubtype1_txt 113
# corp1 33239
# target1 86007
# natlty1 216
# natlty1_txt 216
# targtype2 23
# targtype2_txt 23
# targsubtype2 108
# targsubtype2_txt 108
# corp2 2692
# target2 5044
# natlty2 159
# natlty2_txt 159
# targtype3 21
# targtype3_txt 21
# targsubtype3 93
# targsubtype3_txt 93
# corp3 423
# target3 721
# natlty3 111
# natlty3_txt 111
# gname 3537
# gsubname 1184
# gname2 434
# gsubname2 61
# gname3 117
# ...

# %%
df.isnull().sum()
# Out:
# eventid            0
# iyear              0
# imonth             0
# iday               0
# approxdate    172452
#                ...
# INT_LOG            0
# INT_IDEO           0
# INT_MISC           0
# INT_ANY            0
# related       156653
# Length: 135, dtype: int64

# %%
# Checking for duplicate values
df.duplicated().sum()
# Out:
# 4550

# %% [markdown]
# # Step 4 - Data Cleaning

# %%
#Since there are 135 Columns. We will take only those columns which will help in our Analysis
df.rename(columns={'iyear':'Year','imonth':'Month','iday':'Day','extended':'Duration','country_txt':'Country','region_txt':'Region','attacktype1_txt':'AttackType','target1':'Target','natlty1_txt':'Nationality',
                        'nkill':'Killed','nwound':'Wounded','summary':'Summary','gname':'Group','targtype1_txt':'Target_type','latitude': 'lat',
                       'longitude':'long','weaptype1_txt':'Weapon_type','motive':'Motive','ishostkid':'Host'},inplace=True)
df.columns
# Out:
# Index(['eventid', 'Year', 'Month', 'Day', 'approxdate', 'Duration',
#        'resolution', 'country', 'Country', 'region',
#        ...
#        'addnotes', 'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG',
#        'INT_IDEO', 'INT_MISC', 'INT_ANY', 'related'],
#       dtype='object', length=135)

# %%
df = df[['Year','Month','Day','Duration','Country','Region','city','lat','long','success','suicide','AttackType','Target','Nationality','Group','Motive','Weapon_type','Killed','Wounded','Summary','Target_type','Host']]
df['Casualties']= df['Killed'] + df['Wounded']
df.head(5)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_5200\3577174109.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Casualties']= df['Killed'] + df['Wounded']
#    Year  Month  Day  Duration             Country  \
# 0  1970      7    2         0  Dominican Republic
# 1  1970      0    0         0              Mexico
# 2  1970      1    0         0         Philippines
# 3  1970      1    0         0              Greece
# 4  1970      1    0         0               Japan
#
#                         Region           city        lat        long  success  \
# 0  Central America & Caribbean  Santo Domingo  18.456792  -69.951164        1
# 1                North America    Mexico city  19.371887  -99.086624        1
# ...

# %%
df.tail()
# Out:
#         Year  Month  Day  Duration      Country                      Region  \
# 181686  2017     12   31         0      Somalia          Sub-Saharan Africa
# 181687  2017     12   31         0        Syria  Middle East & North Africa
# 181688  2017     12   31         0  Philippines              Southeast Asia
# 181689  2017     12   31         0        India                  South Asia
# 181690  2017     12   31         0  Philippines              Southeast Asia
#
#                  city        lat        long  success  ...  Nationality  \
# 181686  Ceelka Geelow   2.359673   45.385034        1  ...      Somalia
# 181687         Jableh  35.407278   35.942679        1  ...       Russia
# 181688       Kubentog   6.900742  124.437908        1  ...  Philippines
# 181689         Imphal  24.798346   93.940430        0  ...        India
# 181690  Cotabato City   7.209594  124.241966        0  ...  Philippines
#
# ...

# %%
# Removing the unknowns values from the columnns
df=df[pd.notnull(df.lat)]
df=df[pd.notnull(df.long)]
print("Unknown values are removed from the columns")
# Out:
# Unknown values are removed from the columns

# %%
# Number of Duplicated Values in the dataset
df.duplicated().sum()
# Out:
# 8894

# %%
#Removing the Duplicated values
df.drop_duplicates(keep=False,inplace=True)

# %%
# Checking the Null Values in the dataset
df.isnull().sum()
# Out:
# Year                0
# Month               0
# Day                 0
# Duration            0
# Country             0
# Region              0
# city              426
# lat                 0
# long                0
# success             0
# suicide             0
# AttackType          0
# Target            506
# Nationality      1374
# Group               0
# Motive         116092
# Weapon_type         0
# Killed           8668
# Wounded         14339
# Summary         53923
# Target_type         0
# Host              176
# Casualties      14862
# dtype: int64

# %%
#Filling whereever there is NA values with 0
df.fillna(0)
# Out:
#         Year  Month  Day  Duration             Country  \
# 0       1970      7    2         0  Dominican Republic
# 1       1970      0    0         0              Mexico
# 2       1970      1    0         0         Philippines
# 3       1970      1    0         0              Greece
# 4       1970      1    0         0               Japan
# ...      ...    ...  ...       ...                 ...
# 181686  2017     12   31         0             Somalia
# 181687  2017     12   31         0               Syria
# 181688  2017     12   31         0         Philippines
# 181689  2017     12   31         0               India
# 181690  2017     12   31         0         Philippines
#
#                              Region           city        lat        long  \
# 0       Central America & Caribbean  Santo Domingo  18.456792  -69.951164
# 1                     North America    Mexico city  19.371887  -99.086624
# 2                    Southeast Asia        Unknown  15.478598  120.599741
# ...

# %%
# Checking the datatypes
df.dtypes
# Out:
# Year             int64
# Month            int64
# Day              int64
# Duration         int64
# Country         object
# Region          object
# city            object
# lat            float64
# long           float64
# success          int64
# suicide          int64
# AttackType      object
# Target          object
# Nationality     object
# Group           object
# Motive          object
# Weapon_type     object
# Killed         float64
# Wounded        float64
# Summary         object
# Target_type     object
# Host           float64
# Casualties     float64
# dtype: object

# %%
df.corr()
# Out:
#                 Year     Month       Day  Duration       lat      long  \
# Year        1.000000 -0.003614  0.015988  0.084586  0.146372  0.004171
# Month      -0.003614  1.000000  0.004685 -0.000789 -0.013743 -0.004011
# Day         0.015988  0.004685  1.000000 -0.003041  0.002521 -0.002361
# Duration    0.084586 -0.000789 -0.003041  1.000000 -0.031559  0.000553
# lat         0.146372 -0.013743  0.002521 -0.031559  1.000000  0.001583
# long        0.004171 -0.004011 -0.002361  0.000553  0.001583  1.000000
# success    -0.066470 -0.001440 -0.008825  0.075360 -0.066712 -0.000889
# suicide     0.132745  0.003143  0.002322 -0.036664  0.067903  0.000516
# Killed      0.013456  0.002678 -0.004463  0.027352 -0.022249 -0.000538
# Wounded     0.011992  0.002905 -0.001532 -0.007199  0.015233  0.000235
# Host       -0.010197  0.000508  0.000215  0.356206 -0.026036  0.000338
# Casualties  0.010472  0.003318 -0.001706 -0.005172  0.008445  0.000037
#
# ...

# %%
df.shape
# Out:
# (165254, 23)

# %%
# Count of values in each col of the dataset.
df.nunique()
# Out:
# Year               47
# Month              13
# Day                32
# Duration            2
# Country           204
# Region             12
# city            34913
# lat             48073
# long            47789
# success             2
# suicide             2
# AttackType          9
# Target          83339
# Nationality       214
# Group            3434
# Motive          14300
# Weapon_type        12
# Killed            201
# Wounded           238
# Summary        110904
# Target_type        22
# Host                3
# Casualties        338
# dtype: int64

# %%
df['Year'].value_counts()
# Out:
# 2014    16133
# 2015    14217
# 2016    12735
# 2013    11644
# 2017    10466
# 2012     8279
# 2011     4996
# 2010     4793
# 2008     4734
# 2009     4700
# 1992     4279
# 1991     3694
# 1989     3627
# 2007     3154
# 1988     3081
# 1990     3063
# 1994     2963
# 1984     2720
# 2006     2709
# 1983     2482
# 1997     2395
# 1980     2334
# 1981     2323
# 1996     2299
# 1995     2296
# 1987     2295
# 1982     2222
# 1979     2190
# 1986     2157
# 1985     2122
# 2005     1983
# 2001     1865
# 2000     1746
# 1978     1375
# 1999     1325
# 2002     1286
# 2003     1238
# 1977     1149
# 2004     1131
# 1998      872
# 1976      859
# 1975      704
# 1970      631
# 1974      571
# 1972      509
# 1973      461
# 1971      447
# Name: Year, dtype: int64

# %% [markdown]
# **Number of cities in the dataset**

# %%
df['city'].value_counts()
# Out:
# Baghdad           7553
# Unknown           6084
# Mosul             2104
# Karachi           2083
# Belfast           1984
#                   ...
# Saidgi Village       1
# Tal Abass            1
# Ajeem                1
# Bomadi               1
# Kubentog             1
# Name: city, Length: 34913, dtype: int64

# %% [markdown]
# **Number of region in the Dataset**

# %%
df['Region'].value_counts()
# Out:
# Middle East & North Africa     47293
# South Asia                     42613
# Sub-Saharan Africa             16405
# South America                  15110
# Western Europe                 14645
# Southeast Asia                 11494
# Central America & Caribbean     7958
# Eastern Europe                  4918
# North America                   3325
# East Asia                        690
# Central Asia                     533
# Australasia & Oceania            270
# Name: Region, dtype: int64

# %% [markdown]
# **Number of Attacktype in the Dataset**

# %%
df['AttackType'].value_counts()
# Out:
# Bombing/Explosion                      79302
# Armed Assault                          39433
# Assassination                          18250
# Hostage Taking (Kidnapping)            10467
# Facility/Infrastructure Attack          8888
# Unknown                                 6513
# Unarmed Assault                          896
# Hostage Taking (Barricade Incident)      885
# Hijacking                                620
# Name: AttackType, dtype: int64

# %%
#Statistical Summary of Data
df.describe()
# Out:
#                 Year          Month            Day       Duration  \
# count  165254.000000  165254.000000  165254.000000  165254.000000
# mean     2003.443808       6.471553      15.535073       0.046898
# std        13.103225       3.392396       8.809237       0.211420
# min      1970.000000       0.000000       0.000000       0.000000
# 25%      1992.000000       4.000000       8.000000       0.000000
# 50%      2010.000000       6.000000      15.000000       0.000000
# 75%      2014.000000       9.000000      23.000000       0.000000
# max      2017.000000      12.000000      31.000000       1.000000
#
#                  lat          long        success        suicide  \
# count  165254.000000  1.652540e+05  165254.000000  165254.000000
# mean       23.892268 -4.914495e+02       0.887041       0.039581
# std        18.179665  2.120120e+05       0.316544       0.194974
# min       -53.154613 -8.618590e+07       0.000000       0.000000
# ...

# %% [markdown]
# **INFERENCE**
#
# The presence of outliers is noticeable within the dataset, primarily because there is a substantial disparity between the values at the 75th percentile and the maximum values for variables such as "killed" and "wounded." This discrepancy between the upper quartile and the extreme values suggests the existence of data points that significantly deviate from the typical range of casualties in these incidents, warranting further investigation and potential data cleansing.

# %% [markdown]
# **Feature of data**

# %%
print("Country with the most attacks:",df['country'].value_counts().idxmax())
print("City with the most attacks:",df['city'].value_counts().index[1]) #as first entry is 'unknown'
print("Region with the most attacks:",df['region'].value_counts().idxmax())
print("Year with the most attacks:",df['iyear'].value_counts().idxmax())
print("Month with the most attacks:",df['imonth'].value_counts().idxmax())
# Out:
# Country with the most attacks: 95
# City with the most attacks: Baghdad
# Region with the most attacks: 10
# Year with the most attacks: 2014
# Month with the most attacks: 5

# %% [markdown]
# # Step 5 - Exploratory Data Analysis

# %%
fig,axes = plt.subplots(1,1,figsize=(15,16))
sns.heatmap(df.corr(), annot =True)
plt.show()

# %% [markdown]
# In essence, this code is used to visually represent the relationships between the numerical variables in the DataFrame 'df' by displaying their correlation values as a heatmap, making it easier to identify patterns and associations between the variables.

# %%
# Using histogram to represent realtionship between variables.
df.hist(figsize=(50,30))
plt.show()

# %% [markdown]
# **Number of countries affected by terrorist attacks**

# %%
plt.figure(figsize =(20,10))
sns.barplot(x=df['Country'].value_counts()[:25].index,y =df['Country'].value_counts()[:25].values)
plt.xticks(rotation=90)
plt.xlabel('Countries')
plt.ylabel('Count')
plt.title("Number of Terrorist Activities Country Wise")
plt.show()

# %% [markdown]
# **INFERENCE**
#
# This visualises and compares the number of terrorist activities in the top 25 countries with the highest counts, providing insights into which countries have experienced the most incidents.

# %% [markdown]
# **Number of Terrorist Attack by Region Wise**

# %%
df['Region'].value_counts()
plt.figure(figsize=(20,10))
sns.countplot(x="Region", data=df)
plt.xticks(rotation=70)
plt.show()

# %% [markdown]
# **INFERENCE**
#
# This is used to visualize and compare the distribution of data by region, allowing you to see which regions have the highest frequency of occurrences in the dataset.

# %%
print("Country With Highest Terrorist Attacks:", df['Country'].value_counts().index[0])
print("Region With Highest Terrorist Attacks:", df['Region'].value_counts().index[0])
# Out:
# Country With Highest Terrorist Attacks: Iraq
# Region With Highest Terrorist Attacks: Middle East & North Africa

# %%
# Weapon types used with the help of pie chart
plt.figure(figsize=(10,15))
df['Weapon_type'].value_counts().plot.pie(autopct ="%1.1f%%")
plt.show()

# %% [markdown]
# **Number of Terrorist Attacks Each Year**

# %%
plt.subplots(figsize=(15,6))
sns.countplot('Year',data=df,palette='flare')
plt.xticks(rotation=90)
plt.title('Number Of Terrorist Attacks Each Year')
plt.show()
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# **INFERENCE**
#
# Following 1978, there was an unanticipated rise in attacks, with a subsequent decrease occurring between 1998 and 2004. However, after the year 2004, there was a pronounced and sharp escalation in terrorist activities.In 2014 there was a sharp increase and highest count reached, after which the number of attacks seen to br reduced.

# %% [markdown]
# **Number of Casualties Each Year**

# %%
plt.subplots(figsize=(15,6))
year_cas = df.groupby('Year').Casualties.sum().to_frame().reset_index()
year_cas.columns = ['Year','Casualties']
sns.barplot(x=year_cas.Year, y=year_cas.Casualties, palette='PuBu')
plt.xticks(rotation=90)
plt.title('Number Of Casualties Each Year')
plt.show()

# %% [markdown]
# **INFERENCE**
#
# This is a bar plot that visually represents the number of casualties for each year, allowing viewers to easily compare casualty counts across different years. As we can observe with the regard to the previuos plot here aslo there was a sharp increase in 2014-15 and then there was a decrease in number of casualities.

# %% [markdown]
# **Visualizing the Top 15 Affected Countries**

# %%
plt.subplots(figsize=(18,6))
country_attacks = df.Country.value_counts()[:15].reset_index()
country_attacks.columns = ['Country', 'Total Attacks']
sns.barplot(x=country_attacks.Country, y=country_attacks['Total Attacks'], palette= 'rocket')
plt.xticks(rotation=90)
plt.title('Top 15 Affected Countries')
plt.show()

# %% [markdown]
# **INFERENCE**
#
# This bar plot that visually displays the top 15 countries most affected by attacks, allowing viewers to compare the total number of attacks in these countries.

# %% [markdown]
# **Visualizing the Terrorism in Affected Cities**

# %%
plt.subplots(figsize=(18,6))
city_attacks = df.city.value_counts()[:15].drop('Unknown').reset_index()
city_attacks.columns = ['city', 'Total Attacks']
sns.barplot(x=city_attacks.city, y=city_attacks['Total Attacks'], palette= 'rocket')
plt.xticks(rotation=90)
plt.title('Top 15 Affected Cities')
plt.show()

# %% [markdown]
# **Visualizing the number of total attacks and casualties region wise**

# %%
region_attacks = df.Region.value_counts().to_frame().reset_index()
region_attacks.columns = ['Region', 'Total Attacks']
region_cas = df.groupby('Region').Casualties.sum().to_frame().reset_index()
region_cas.columns = ['Region', 'Casualties']
# city_cas.drop('Unknown', axis=0, inplace=True)
region_tot = pd.merge(region_attacks, region_cas, how='left', on='Region').sort_values('Total Attacks', ascending=False)
# fig = plt.figure()
# fig.subplots()
sns.set_palette('RdBu')
region_tot.plot.bar(x='Region', width=0.6)
plt.xticks(rotation=90)
plt.title('Number Of Total Attacks and Casualties by Region')
fig = plt.gcf()
fig.set_size_inches(16,10)
plt.show()

# %% [markdown]
# **INFERENCE**
#
# As we can observe the grouped bar plot that visually compares the total number of attacks and casualties by region. It provides a clear overview of the regions with the highest and lowest occurrences of attacks and their corresponding casualty counts.If you notice the graph, total attacks and casualties by region, the Middle East and North Africa had the most attacks and casualties.

# %% [markdown]
# **Visualization of Attack Type vs Region**

# %%
pd.crosstab(df.Region,df.AttackType).plot.barh(stacked=True,width=1,color=sns.color_palette('coolwarm_r',9))
fig=plt.gcf()
fig.set_size_inches(12,8)
plt.show()

# %% [markdown]
# **INFERENCE**
#
# This shows a horizontal stacked bar plot that shows the distribution of different attack types within each region. Each region is represented by a horizontal bar, and the length of each segment within the bar corresponds to the frequency of a specific attack type. This plot provides an overview of the predominant attack types in each region and allows for easy comparison between regions. It is observed from the graph, total attacks and casualties by region, the Middle East and North Africa had the most attacks and casualties.

# %% [markdown]
# **END NOTE**
#
# The nation most severely afflicted by terrorist attacks is Iraq, while the region bearing the brunt of such incidents is the Middle East & North Africa. Notably, there was an upsurge in terrorist activities between 1977 and 1981. Bombings and explosions emerged as the predominant attack method, with private citizens as the favored targets, followed closely by military properties. Explosives are the most commonly employed weapons. Bellfast and Salvador have experienced the highest incident rates among cities. An unknown group conducted the majority of these attacks. In 2014, there was the highest frequency of terrorist attacks.
